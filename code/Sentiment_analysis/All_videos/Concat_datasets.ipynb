# %% [markdown]
# <a href="https://colab.research.google.com/github/calzateu/Numerical_Analysis/blob/main/code/Sentiment_analysis/All_videos/Concat_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 = pd.read_csv('Dataset-with-sentiments1.csv')
df2 = pd.read_csv('Dataset-with-sentiments2.csv')

new_df = pd.concat([df1, df2])

new_df.to_csv('Dataset-with-sentiments.csv')
